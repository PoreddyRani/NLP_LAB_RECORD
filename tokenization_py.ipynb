# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/NLP_LAB_RECORD/blob/main/tokenization_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="hello,world ! this is a simple tokenization example."
tokens=text.split()
print(tokens)
# Out:
# ['hello,world', '!', 'this', 'is', 'a', 'simple', 'tokenization', 'example.']
