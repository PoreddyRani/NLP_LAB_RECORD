# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/NLP_LAB_RECORD/blob/main/unigram_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = "I love NLP and natural language processing."
unigrams = sentence.split()
print("Unigrams:", unigrams)
# Out:
# Unigrams: ['I', 'love', 'NLP', 'and', 'natural', 'language', 'processing.']
