# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/NLP_LAB_RECORD/blob/main/bigram_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = "I love NLP and natural language processing."
words = sentence.split()
bigrams = [(words[i], words[i+1]) for i in range(len(words)-1)]
print("Bigrams:", bigrams)
# Out:
# Bigrams: [('I', 'love'), ('love', 'NLP'), ('NLP', 'and'), ('and', 'natural'), ('natural', 'language'), ('language', 'processing.')]
