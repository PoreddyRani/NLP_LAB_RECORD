# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/NLP_LAB_RECORD/blob/main/spelling_correction_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

text = "I hav a speling eror"

blob = TextBlob(text)

corrected = blob.correct()

print("Original:", text)
print("Corrected:", corrected)
# Out:
# Original: I hav a speling eror
# Corrected: I had a spelling error
